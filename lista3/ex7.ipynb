# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

# %%
def solucao(x0, A, epsilon):
    delta = np.inf
    x = x0
    y = None
    lamb = None
    
    while delta > epsilon:
        y = A @ x0
        x = y/np.linalg.norm(y)
