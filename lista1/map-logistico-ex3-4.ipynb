# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

import scienceplots
plt.style.use(['science', 'notebook', 'grid'])

# %%
#função para gerar sequência

x_0 = 0.1
N = 5000

def gerar_sequencia(a):
    sequencia = [x_0]
    
    for n in range(1,N+1):
        x_n = a*sequencia[n-1]*(1-sequencia[n-1])
        sequencia.append(x_n)
        
    return sequencia

# %%
#valores de a entre 0 e 4, como pedido no enunciado

a_valores = np.linspace(0.1, 4, 5)
x_data = np.array(range(N+1))
y_data_array = []

#gear sequência e calcular média e variância 

for a in a_valores:
    sequencia = gerar_sequencia(a)
    y_data_array.append(sequencia)
    
    np.array(sequencia).var()
    
    x_bar_np = np.array(sequencia).mean()
    x_bar = (1/N) * sum(sequencia)
    
    x_var_np = np.array(sequencia).var(ddof=1)
    x_var = (1/(N-1))* sum([(x_i - x_bar)**2 for x_i in sequencia])
    
    print("-----------------------")
    print("a = " + str(a))
    
    print("Média Numpy:  " + str(x_bar_np))
    print("Média:  " + str(x_bar))
    
    print()
    
    print("Variância Numpy:  " + str(x_var_np))
    print("Variância:  " + str(x_var))
    
    print("-----------------------")
# Out:
# -----------------------
# a = 0.1
# Média Numpy:  2.1993783387622988e-05
# Média:  2.1998182144300512e-05
#
# Variância Numpy:  2.01587687804241e-06
# Variância:  2.0162801340878333e-06
# -----------------------
# -----------------------
# a = 1.075
# Média Numpy:  0.06983386597997375
# Média:  0.06984783275316954
#
# Variância Numpy:  9.850811892402265e-07
# Variância:  9.85473393686362e-07
# -----------------------
# -----------------------
# a = 2.05
# Média Numpy:  0.511989949045203
# Média:  0.512092347035002
#
# Variância Numpy:  6.485331675072398e-05
# Variância:  6.487677955201001e-05
# -----------------------
# -----------------------
# a = 3.025
# Média Numpy:  0.6650794693159517
# Média:  0.6652124852098018
#
# Variância Numpy:  0.0028475236918036957
# Variância:  0.0028481110107728452
# -----------------------
# -----------------------
# a = 4.0
# Média Numpy:  0.5022300520227297
# Média:  0.5023304980331337
#
# Variância Numpy:  0.12446461444030983
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#plots das sequências para vários valores de a

for i in range(len(a_valores)):
    plt.scatter(x_data, y_data_array[i], label = "a = " + str(a_valores[i]), s =5, marker='.')
    
plt.xlabel("n")
plt.ylabel(r"$x_n$")
plt.title(r"$X_n$ por $n$")

plt.legend()
