# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

# %%
img = mpimg.imread('stinkbug.png') #carregar imagem
plt.imshow(img) #mostrar imagem

# %%
A = img[:, :, 0] #carregar primeiro canal
plt.imshow(A) #ver canal

# %%
plt.imshow(A, cmap="hot") #outro mapa

# %%
plt.imshow(A, cmap="nipy_spectral") #outro mapa
